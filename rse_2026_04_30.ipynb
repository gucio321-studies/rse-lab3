# %%
# echo: false
import numpy as np
pi = np.atan(1)*4
print(pi)
# Out:
# 3.141592653589793

# %% [markdown]
# ## Wartość liczby $pi$
#
# Wyznaczono wartość liczby pi równą $\pi = `{python} f"{pi:5g}"`$ <!-5g is for 5 significiant numbers-->
